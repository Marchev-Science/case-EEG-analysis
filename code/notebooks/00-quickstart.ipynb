# %% [markdown]
# # 00 — Quickstart
#
# Sanity-check that you can load one recording and plot a few seconds of it.
#
# 1. Record a 60 s eyes-closed baseline (see `docs/03-data-collection.md`).
# 2. Save it under `data/raw/sub-001/ses-S001/eeg/` following the naming convention.
# 3. Run the cells below.

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

DATA_PATH = Path('../../data/raw/sub-001/ses-S001/eeg/sub-001_ses-S001_task-baseline_run-001_eeg.xdf')
DATA_PATH

# %%
# TODO: implement code/data_access/load_xdf.py first.
# from code.data_access import load_xdf
# rec = load_xdf(DATA_PATH)
# print(rec.channel_names, rec.sample_rate, rec.eeg.shape)

# %%
# Plot first 10 seconds of all channels — uncomment once loader works.
# fs = rec.sample_rate
# n = int(10 * fs)
# fig, axes = plt.subplots(rec.eeg.shape[0], 1, figsize=(10, 6), sharex=True)
# for ax, ch, name in zip(axes, rec.eeg[:, :n], rec.channel_names):
#     ax.plot(rec.times[:n], ch)
#     ax.set_ylabel(name)
# axes[-1].set_xlabel('time (s)')
# plt.tight_layout()
