# %% [markdown]
# # 01 — Analysis Template
#
# End-to-end skeleton for your study. Each section is a TODO.
#
# 1. Load all subjects
# 2. Pre-process
# 3. Epoch by markers
# 4. Extract features
# 5. Statistics or ML
# 6. Plot results
#
# Save figures to `reports/figures/` and reference them from your report.

# %%
# 1. LOAD
# from code.data_access import load_xdf
# subjects = sorted(Path('../../data/raw').glob('sub-*'))

# %%
# 2. PRE-PROCESS
# from code.preprocessing import bandpass, notch, reject_outliers

# %%
# 3. EPOCH

# %%
# 4. FEATURES
# from code.features import band_power_per_epoch

# %%
# 5. STATS / ML
# from code.models import loso_classify

# %%
# 6. PLOT
